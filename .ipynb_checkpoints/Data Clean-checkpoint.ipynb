# %%
# Import libraries
import pandas as pd
import numpy as np

# %%
# Import data
df =  pd.read_csv("everest.csv", low_memory=False)
df
# Out:
#            expid  membid peakid  myear  mseason                      fname  \
# 0      EVER88401      15   EVER   1988        4                    Maurits
# 1      EVER88401      13   EVER   1988        4                    Christa
# 2      EVER88401      14   EVER   1988        4                       Rudy
# 3      EVER88401      19   EVER   1988        4                   Ang Rita
# 4      EVER88401      20   EVER   1988        4  Lhakpa Dorje (Ang Lhakpa)
# ...          ...     ...    ...    ...      ...                        ...
# 21896  EVER20103      10   EVER   2020        1                   Tai-Gang
# 21897  EVER20103      11   EVER   2020        1                        Wei
# 21898  EVER20103       9   EVER   2020        1                   Hong-Zhi
# 21899  EVER20103      12   EVER   2020        1                   Xiao-Lin
# 21900  EVER20103       8   EVER   2020        1                  Cheng-Jie
#
#                    lname sex  age birthdate  ...  totmembers  smtmembers  \
# 0                Vreudge   M    0     -   -  ...          17           0
# 1      Van Schaerdenburg   F    0     -   -  ...          17           0
# 2              Van Snick   M    0     -   -  ...          17           0
# 3                 Sherpa   M    0     -   -  ...          17           0
# 4                 Sherpa   M    0     -   -  ...          17           0
# ...                  ...  ..  ...       ...  ...         ...         ...
# 21896              Huang   M    0     -   -  ...          20          14
# 21897                 Li   M    0     -   -  ...          20          14
# 21898                 Hu   M    0     -   -  ...          20          14
# 21899                 Li   M    0     -   -  ...          20          14
# 21900                 Hu   M    0     -   -  ...          20          14
#
#       mdeaths tothired nohired smthired  hdeaths      bcdate   pkname  heightm
# 0           0       10   False        0        1  10/11/1988  Everest     8849
# 1           0       10   False        0        1  10/11/1988  Everest     8849
# 2           0       10   False        0        1  10/11/1988  Everest     8849
# 3           0       10   False        0        1  10/11/1988  Everest     8849
# 4           0       10   False        0        1  10/11/1988  Everest     8849
# ...       ...      ...     ...      ...      ...         ...      ...      ...
# 21896       0       22   False       21        0  23/04/2020  Everest     8849
# 21897       0       22   False       21        0  23/04/2020  Everest     8849
# 21898       0       22   False       21        0  23/04/2020  Everest     8849
# 21899       0       22   False       21        0  23/04/2020  Everest     8849
# 21900       0       22   False       21        0  23/04/2020  Everest     8849
#
# [21901 rows x 85 columns]

# %%
df.columns
# Out:
# Index(['expid', 'membid', 'peakid', 'myear', 'mseason', 'fname', 'lname',
#        'sex', 'age', 'birthdate', 'yob', 'calcage', 'citizen', 'status',
#        'residence', 'occupation', 'leader', 'deputy', 'bconly', 'nottobc',
#        'support', 'disabled', 'hired', 'sherpa', 'tibetan', 'msuccess',
#        'mclaimed', 'mdisputed', 'msolo', 'mtraverse', 'mski', 'mparapente',
#        'mspeed', 'mhighpt', 'mperhighpt', 'msmtdate1', 'msmtdate2',
#        'msmtdate3', 'msmttime1', 'msmttime2', 'msmttime3', 'mroute1',
#        'mroute2', 'mroute3', 'mascent1', 'mascent2', 'mascent3', 'mo2used',
#        'mo2none', 'mo2climb', 'mo2descent', 'mo2sleep', 'mo2medical',
#        'mo2note', 'death', 'deathdate', 'deathtime', 'deathtype', 'deathhgtm',
#        'deathclass', 'msmtbid', 'msmtterm', 'hcn', 'mchksum', 'host', 'comrte',
#        'stdrte', 'route1', 'route2', 'route3', 'route4', 'nation', 'leaders',
#        'sponsor', 'termreason', 'totmembers', 'smtmembers', 'mdeaths',
#        'tothired', 'nohired', 'smthired', 'hdeaths', 'bcdate', 'pkname',
#        'heightm'],
#       dtype='object')

# %% [markdown]
# ### Definitions
#
# <b>expid</b> - Expedition id
#
# <b>membid</b> - Member id
#
# <b>*NOTE:*</b> - Individua record id is compound key of expedition id + member id
#
# -----
#
# <b>bconly</b> - BC / Advanced BC only (Y/N) if yes, The member did not climb above base camp (or advanced
# base camp in cases where the path from base camp does not require technical climbing skills)
#
# <b>nottobc</b> - Not to base camp (Y/N) if yes, The member did not reach base camp
#
# <b>hired</b> - The person was hired by the expedition
#
# <b>msolo</b> - Solo (Y/N)
#
# <b>sherpa</b> - Sherpa (Y/N)
#
# <b>tibetan</b> - Tibetan (Y/N)
#
# <b>mhighpt</b> - Expedition high-point reached (Y/N)
#
# <b>mperhighpt</b> - Personal high-point (m)
#
# <b>msmdate1</b> - 1st summit / high-point date
#
# <b>msmdate2</b> - 2nd summit date
#
# <b>msmdate3</b> - 3rd summit date
#
# <b>mroute1</b> - 1st ascent route
#
# <b>mroute2</b> - 2nd ascent route
#
# <b>mroute3</b> - 3rd ascent route
#
# <b>mo2used</b> - Oxygen used (Y/N)
#
# <b>mo2none</b> - Oxygen not used (Y/N)
#
# <b>deathhgtm</b> - Death Height (m)
#
# <b>msmtbid</b> - Summit Bid:
# ```
# 0 – Unspecified
# 1 – No summit bid
# 2 – Aborted below high camp
# 3 – Aborted at high camp
# 4 – Aborted above high camp
# 5 – Successful summit bid
# ```
# <b>nohired</b> - No hired personnel used (above BC)

# %%
# Select the required columns 
filtered_df = df[['expid', 'membid', 'myear', 'fname', 'lname', 'sex', 'calcage', 'citizen', 'occupation', 'sherpa', 
                  'tibetan', 'msolo', 'msuccess', 'mhighpt', 'mperhighpt', 'msmtdate1', 'msmtdate2', 'msmtdate3', 
                  'msmttime1', 'msmttime2', 'msmttime3', 'bconly', 'nottobc', 'route1', 'route2', 'route3', 
                  'route4', 'mo2used', 'mo2none', 'death', 'deathdate', 'deathhgtm', 'msmtbid', 'nohired', 'hired']]

# %%
filtered_df
# Out:
#            expid  membid  myear                      fname              lname  \
# 0      EVER88401      15   1988                    Maurits            Vreudge
# 1      EVER88401      13   1988                    Christa  Van Schaerdenburg
# 2      EVER88401      14   1988                       Rudy          Van Snick
# 3      EVER88401      19   1988                   Ang Rita             Sherpa
# 4      EVER88401      20   1988  Lhakpa Dorje (Ang Lhakpa)             Sherpa
# ...          ...     ...    ...                        ...                ...
# 21896  EVER20103      10   2020                   Tai-Gang              Huang
# 21897  EVER20103      11   2020                        Wei                 Li
# 21898  EVER20103       9   2020                   Hong-Zhi                 Hu
# 21899  EVER20103      12   2020                   Xiao-Lin                 Li
# 21900  EVER20103       8   2020                  Cheng-Jie                 Hu
#
#       sex  calcage      citizen                                occupation  \
# 0       M       49      Belgium                                 Physician
# 1       F       30  Netherlands                                 Physician
# 2       M       32      Belgium  Furniture maker, cabinet maker & artisan
# 3       M       40        Nepal                      High-altitude porter
# 4       M       29        Nepal                                       NaN
# ...    ..      ...          ...                                       ...
# 21896   M       47        China                                       NaN
# 21897   M        0        China                                       NaN
# 21898   M       57        China                                       NaN
# 21899   M       35        China                                       NaN
# 21900   M        0        China                                       NaN
#
#        sherpa  ...  route3  route4  mo2used  mo2none  death   deathdate  \
# 0       False  ...     NaN     NaN    False     True  False       -   -
# 1       False  ...     NaN     NaN    False     True  False       -   -
# 2       False  ...     NaN     NaN     True    False  False       -   -
# 3        True  ...     NaN     NaN    False     True  False       -   -
# 4        True  ...     NaN     NaN     True    False   True  23/12/1988
# ...       ...  ...     ...     ...      ...      ...    ...         ...
# 21896   False  ...     NaN     NaN     True    False  False       -   -
# 21897   False  ...     NaN     NaN     True    False  False       -   -
# 21898   False  ...     NaN     NaN     True    False  False       -   -
# 21899   False  ...     NaN     NaN     True    False  False       -   -
# 21900   False  ...     NaN     NaN     True    False  False       -   -
#
#       deathhgtm msmtbid  nohired  hired
# 0             0       1    False  False
# 1             0       1    False  False
# 2             0       4    False  False
# 3             0       4    False   True
# 4          8700       4    False   True
# ...         ...     ...      ...    ...
# 21896         0       1    False  False
# 21897         0       5    False  False
# 21898         0       5    False  False
# 21899         0       5    False  False
# 21900         0       5    False  False
#
# [21901 rows x 35 columns]

# %%
# Find the number of null items in route column
len(df[df['route1'].isnull()==True])
# Out:
# 200

# %%
# Remove the 200 items with missing route
df = df[df['route1'].isnull() != True]

# %%
x = df[df['route1'] == 'N Col-N Face'] 
len(x)

# ) or (df['route'] == 'S Col-N Face')]
# Out:
# 479

# %%
filtered_df = filtered_df[filtered_df['route1'].isnull() != True]

# %%
# Simplify the route names to either northern or souther approach
for index, row in filtered_df.iterrows():
    if ('Col-N' in row['route1']) or ('N Col' in row['route1']) or ('N Face' in row['route1']) or \
       ('from N' in row['route1']) :
        filtered_df.loc[index,'new_route'] = 'North'
    if ('Col-S' in row['route1']) or ('S Col' in row['route1']) or ('S Face' in row['route1']) or \
       ('from S' in row['route1']) or ('SW Face' in row['route1']):
        filtered_df.loc[index,'new_route'] = 'South'
    if ('Lho' in row['route1']) or ('Lho' in row['route1']) or ('S Pillar' in row['route1']):
        filtered_df.loc[index,'new_route'] = 'Other'

# %%
# drop list:
'Lho La-W Ridge (to 7800m)'
 'Lho La-W Ridge (not to Hornbein Couloir)', 'W Cwm-W Ridge'



filtered_df.route1.unique()
# Out:
# array(['S Col-SE Ridge', 'SW Face (Bonington rte)', 'N Col-N Face',
#        'N Face (Japanese Couloir)', 'N Col-N Ridge-N Face',
#        'NE Ridge (to 7030m)', 'N Face (Great Couloir)',
#        'N Face (Hornbein Couloir)', 'N Col-NE Ridge',
#        'W Ridge-N Arete-N Face (to 7420m)', 'Lho La-W Ridge',
#        'W Ridge-N Face (Hornbein Couloir)', 'Lho La-W Ridge (to 7200m)',
#        'N Col (to 7000m)', 'N Face (Japanese & Hornbein Couloirs)',
#        'NE Ridge', 'W Ridge from N (7170m)',
#        'SW Face (Bonington 1972 rte) (to 8250m)',
#        'S Pillar (Polish route to C1)', 'N Col-N Face (Great Couloir)',
#        'N Col-N Face (Great Couloir)-W Ridge',
#        'N Face (Great Couloir)-W Ridge', 'S Pillar (USA 1981 rte)',
#        'W Ridge from N', 'Eastern most buttress of E Face', 'E Face',
#        'NE Ridge-N Face', 'Face between N and NE Ridges',
#        'S Pillar-SE Ridge', 'Lho La-W Ridge from S', 'SW Face',
#        'S Pillar (to 7000m)',
#        'Khumbutse-W Ridge-N Face (Hornbein Couloir)',
#        'SW Face up; SE Ridge-S Col down', 'S Pillar',
#        'Lho La-W Ridge (to 7800m)',
#        'Lho La-W Ridge (not to Hornbein Couloir)', 'W Cwm-W Ridge',
#        'S Pillar up; SE Ridge-S Col down', 'SW Face (to 6500m)',
#        'N Col-NE Ridge up, SE Ridge-S Col down',
#        'Khumbutse-W Ridge (to 7699m)', 'N Col (Messner 1980 rte)',
#        'N Face', 'N Face (direct)', 'Lho La-W Ridge (to 7450m)',
#        'Lho La-W Ridge (to 7400m)', 'S Pillar (to 7700m)',
#        'W Cwm-W Ridge (to 7500m)', 'W Cwm-W Ridge (to 7400m)',
#        'A couloir just W of N Col-N Ridge', 'E Ridge (to NE Ridge)',
#        'NE Ridge (to 8000m)', 'N Col-NE Ridge (to 8550m)',
#        'W Ridge from N via Hornbein Couloir', 'N Col-N Face/N Ridge',
#        'NE Ridge (UK 1982 Spring rte)', 'E Face-S Col-SE Ridge',
#        'S Couloir/S Pillar', 'SW Face (to 7250m)',
#        'W Cwm-W Ridge-N Face (Hornbein Couloir)', 'N Face-N Ridge',
#        'W Cwm-W Ridge (to 6800m)', 'N Rib-W Ridge',
#        'N Face (Great Couloir) (to 8000m)', 'E Face-S Col (Venables rte)',
#        'Couloir on E side of N Ridge (to 8000m)',
#        'N Col-N Ridge-N Face up; Great Couloir down', 'N Col',
#        'N Face (Great Couloir) (to 7160m)',
#        'N Col-NE Ridge up; SE Ridge-S Col down', 'SW Face (to 8450m)',
#        'NE Ridge (to 7700m)', 'N Col-N Face-N Ridge',
#        'N Face (Japanese & Hornbein Couloirs) (to 6600m)',
#        'N Face (left of Great Couloir)',
#        'Left side of N Face into Great Couloir',
#        'W Ridge direct from N (to 7925m)',
#        'Face between N and NE Ridges (to 8000m)', 'SW Face rib-W Ridge',
#        'S Plr-S Col-SE Ridge up; S Col-Lhot W Face down',
#        'S Pillar-S Col-SE Ridge',
#        'NE Ridge-N Ridge-N Face up; N Ridge-N Col down',
#        'N Col-N Ridge-N Face (Great Couloir)',
#        'W Rongbuk Glacier-N Col-NE Ridge',
#        'N Col-Great Couloir (to 8300m)',
#        'N Face (Japanese Couloir) (to 7300m)',
#        'Lho La-W Ridge up; N Face (Hornbein)-W Ridge down',
#        'N Face (recon to 6400m)', 'N Face (a rib to 7500m)-N Ridge',
#        'SW Face-S Smt', 'N Face (Japanese Coulior) (to 6400m)',
#        'W Cwm-W Ridge (to 7300m)', 'S Col (skiing)', 'SW Face (recon)',
#        'S Col (recon)', 'N Col-NE Ridge (training)', 'S Col',
#        'N Face (Japanese Couloir area)', 'W, N & E sides',
#        'N Col-N Face (Norton to 8570m)', 'N Col (recon to 7000m)',
#        'E Rongbuk Glacier-N Col', 'Khumbu Glacier (recon)',
#        'Khumbu Glacier-Khumbu Icefall (recon)', 'N side (recon)',
#        'N Col (training, recon)', 'N Col-NE Ridge (training for 1975)',
#        'S side (attempt rumored)', 'N Ridge (recon, training)',
#        'S Col-SE Ridge (to 7400m)', 'N Col (research)',
#        'N Face (Japanese Couloir) (to 7100m)', 'S Couloir',
#        'N Col-NERidge', 'Left slope of E Ridge (to 6800m)',
#        'N Col up, Hornbein Couloir down',
#        'N side (success reported, not confirmed)', 'W Ridge', 'E Ridge',
#        'N Face up; N Col down', 'N Col-NE Ridge (recon)',
#        'N Face (to 6000m)', 'S Col-SE Ridge (up); N Col-NE Ridge (down)',
#        'E Ridge (to 6000m)', 'N Col-NE Ridge (up); S Col-SE Ridge (down)',
#        'N Col-NE Ridge (up); Great Couloir (down)',
#        'N Face (Japanese Couloir-Hornbein Couloir)',
#        'N Col-NE Ridge (up); SE Ridge-S Col (down)',
#        'SW Face (up); SE Ridge-S Col (down)', 'SE Col-SE Ridge',
#        'N Col-NE Ridge (to 7500m)', 'N Col-N Face (Great Colouir)',
#        'N Col-NE RIdge', 'N Face (to 6300m)',
#        'N Face via Japanese & Hornbein Couloirs (to 6750m)',
#        'Geneva Spur-SE Ridge', 'N Face (Norton Couloir)',
#        'W Ridge-SE Ridge-W Face of Lhotse', 'S Col_SE Ridge',
#        'Khumbu Icefall-W Shoulder-Hornbein Couloir', 'SE Ridge',
#        'Genava Spur-SE Ridge'], dtype=object)

# %%
filtered_df['new_route'].isna().sum()
# Out:
# 693

# %%
# Export the file to csv
filtered_df.to_csv('clean_data.csv', index=False)

# %% [markdown]
# ### Columns with missing values (issues for deep learning)
#
# fname (14)
#
# lname (60)
#
# Occupation (733)
#
# calcage = 0 (813)

# %%
from sqlalchemy import create_engine

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import inspect

from sqlalchemy import Column, Float, Integer, String
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
# Establish database connection
# engine = create_engine('postgres///postgres@localhost:5432/everest_db')
test = df.copy()



# Establish connection to the youth_crime database
# connection_string = "postgres:postgres@localhost:5432/youth_crime_db"
engine = create_engine(f'postgresql://postgres:Garden12@localhost:5432/everest_db')
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3516628b754e> in <module>
#       7 # Establish connection to the youth_crime database
#       8 # connection_string = "postgres:postgres@localhost:5432/youth_crime_db"
# ----> 9 engine = create_engine(f'postgresql://postgres:Garden12@localhost:5432/everest_db')
#      10 conn = engine.connect()
#
# NameError: name 'create_engine' is not defined
